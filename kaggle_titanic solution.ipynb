# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
train = pd.read_csv('train.csv')       #loading train and test datasets
test = pd.read_csv('test.csv')
print(train.shape)
print(test.shape)
# Out:
# (891, 12)
# (418, 11)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.drop('PassengerId', axis=1, inplace=True) #passenger id is not a factor for survival drop it
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train.info()         #check for null enteries in datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.6+ KB

# %%
test.info()     #check for null enteries in datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
# Analysing effect of various attributes on survival using bar graph for help in mapping and encoding

# %%
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
bar_chart('Parch')

# %%
bar_chart('Embarked')

# %%
train_test_data = [train, test]            # combining train and test dataset for mapping various attribute values

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Mme           1
# Lady          1
# Countess      1
# Sir           1
# Don           1
# Jonkheer      1
# Capt          1
# Ms            1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Rev         2
# Col         2
# Dr          1
# Dona        1
# Ms          1
# Name: Title, dtype: int64

# %%
# encoding titles 
# Mr : 0
# Miss : 1
# Mrs: 2
# Others: 3
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Title
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S      0
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C      2
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3  female  35.0      1      0            113803  53.1000  C123        S      2
# 4    male  35.0      0      0            373450   8.0500   NaN        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      2
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      2

# %%
train.drop('Name', axis=1, inplace=True)          # name is not needed for survival so dropped
test.drop('Name', axis=1, inplace=True)

# %%
#encoding sex
# male: 0 
# female: 1
sex_mapping = {"male": 0, "female": 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
# filling null values for age with median age for each title (Mr, Mrs, Miss, Others)
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)
test["Age"].fillna(test.groupby("Title")["Age"].transform("median"), inplace=True)

# %%
train.head()
train.groupby("Title")["Age"].transform("median")
# Out:
# 0      30.0
# 1      35.0
# 2      21.0
# 3      35.0
# 4      30.0
# 5      30.0
# 6      30.0
# 7       9.0
# 8      35.0
# 9      35.0
# 10     21.0
# 11     21.0
# 12     30.0
# 13     30.0
# 14     21.0
# 15     35.0
# 16      9.0
# 17     30.0
# 18     35.0
# 19     35.0
# 20     30.0
# 21     30.0
# 22     21.0
# 23     30.0
# 24     21.0
# 25     35.0
# 26     30.0
# 27     30.0
# 28     21.0
# 29     30.0
#        ...
# 861    30.0
# 862    35.0
# 863    21.0
# 864    30.0
# 865    35.0
# 866    21.0
# 867    30.0
# 868    30.0
# 869     9.0
# 870    30.0
# 871    35.0
# 872    30.0
# 873    30.0
# 874    35.0
# 875    21.0
# 876    30.0
# 877    30.0
# 878    30.0
# 879    35.0
# 880    35.0
# 881    30.0
# 882    21.0
# 883    30.0
# 884    30.0
# 885    35.0
# 886     9.0
# 887    21.0
# 888    21.0
# 889    30.0
# 890    30.0
# Name: Age, Length: 891, dtype: float64

# %%
train.info()       # checking if all null values for age are filled by median
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null int64
# Age         891 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# Title       891 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 76.6+ KB

# %%
test.info()        # checking if all null values for age are filled by median
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Title          418 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 36.0+ KB

# %%
# dividing passengers based on age into categories(encoded) as:
# child: 0
# young: 1
# adult: 2
# mid-age: 3
# senior: 4

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0,
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1,
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2,
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3,
    dataset.loc[ dataset['Age'] > 62, 'Age'] = 4

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0       3    0  1.0      1      0         A/5 21171   7.2500   NaN
# 1         1       1    1  3.0      1      0          PC 17599  71.2833   C85
# 2         1       3    1  1.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1       1    1  2.0      1      0            113803  53.1000  C123
# 4         0       3    0  2.0      0      0            373450   8.0500   NaN
#
#   Embarked  Title
# 0        S      0
# 1        C      2
# 2        S      1
# 3        S      2
# 4        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    0  2.0      0      0   330911   7.8292   NaN
# 1          893       3    1  3.0      1      0   363272   7.0000   NaN
# 2          894       2    0  3.0      0      0   240276   9.6875   NaN
# 3          895       3    0  2.0      0      0   315154   8.6625   NaN
# 4          896       3    1  1.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q      0
# 1        S      2
# 2        Q      0
# 3        S      0
# 4        S      2

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
# most of the passengers (more than 50%) of each class are from S embarked
# so filling null values in embarked with S embark

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0       3    0  1.0      1      0         A/5 21171   7.2500   NaN
# 1         1       1    1  3.0      1      0          PC 17599  71.2833   C85
# 2         1       3    1  1.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1       1    1  2.0      1      0            113803  53.1000  C123
# 4         0       3    0  2.0      0      0            373450   8.0500   NaN
#
#   Embarked  Title
# 0        S      0
# 1        C      2
# 2        S      1
# 3        S      2
# 4        S      0

# %%
#encoding embark
embarked_mapping = {"S": 0, "C": 1, "Q": 2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %%
# fill null values for Fare with median fare for each Pclass
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)
train.head(50)
# Out:
#     Survived  Pclass  Sex  Age  SibSp  Parch            Ticket      Fare  \
# 0          0       3    0  1.0      1      0         A/5 21171    7.2500
# 1          1       1    1  3.0      1      0          PC 17599   71.2833
# 2          1       3    1  1.0      0      0  STON/O2. 3101282    7.9250
# 3          1       1    1  2.0      1      0            113803   53.1000
# 4          0       3    0  2.0      0      0            373450    8.0500
# 5          0       3    0  2.0      0      0            330877    8.4583
# 6          0       1    0  3.0      0      0             17463   51.8625
# 7          0       3    0  0.0      3      1            349909   21.0750
# 8          1       3    1  2.0      0      2            347742   11.1333
# 9          1       2    1  0.0      1      0            237736   30.0708
# 10         1       3    1  0.0      1      1           PP 9549   16.7000
# 11         1       1    1  3.0      0      0            113783   26.5500
# ...

# %%
# graphical analysis to decide ranges for fare encoding

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
 
plt.show()
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0, 20)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 30)
# Out:
# (0, 30)

# %%
# dividing fare into 4 categories based on range for easy encoding/mapping using above graphical analysis:
#     0 - 17 : 0
#     18 - 30 : 1
#     31 - 100 : 2
#     more than 100 : 3

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 17, 'Fare'] = 0,
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1,
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] = 2,
    dataset.loc[ dataset['Fare'] > 100, 'Fare'] = 3

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  Fare Cabin  \
# 0         0       3    0  1.0      1      0         A/5 21171   0.0   NaN
# 1         1       1    1  3.0      1      0          PC 17599   2.0   C85
# 2         1       3    1  1.0      0      0  STON/O2. 3101282   0.0   NaN
# 3         1       1    1  2.0      1      0            113803   2.0  C123
# 4         0       3    0  2.0      0      0            373450   0.0   NaN
#
#    Embarked  Title
# 0         0      0
# 1         1      2
# 2         0      1
# 3         0      2
# 4         0      0

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

# %%
Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass3 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
cabin_mapping = {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %%
# filling null values of cabin with median fare for each Pclass
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace=True)
test["Cabin"].fillna(test.groupby("Pclass")["Cabin"].transform("median"), inplace=True)

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
#using graph to decide encoding for family size
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 11.0)

# %%
family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['FamilySize'].map(family_mapping)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  Fare  Cabin  \
# 0         0       3    0  1.0      1      0         A/5 21171   0.0    2.0
# 1         1       1    1  3.0      1      0          PC 17599   2.0    0.8
# 2         1       3    1  1.0      0      0  STON/O2. 3101282   0.0    2.0
# 3         1       1    1  2.0      1      0            113803   2.0    0.8
# 4         0       3    0  2.0      0      0            373450   0.0    2.0
#
#    Embarked  Title  FamilySize
# 0         0      0         0.4
# 1         1      2         0.4
# 2         0      1         0.0
# 3         0      2         0.4
# 4         0      0         0.0

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  Fare  Cabin  \
# 0         0       3    0  1.0      1      0         A/5 21171   0.0    2.0
# 1         1       1    1  3.0      1      0          PC 17599   2.0    0.8
# 2         1       3    1  1.0      0      0  STON/O2. 3101282   0.0    2.0
# 3         1       1    1  2.0      1      0            113803   2.0    0.8
# 4         0       3    0  2.0      0      0            373450   0.0    2.0
#
#    Embarked  Title  FamilySize
# 0         0      0         0.4
# 1         1      2         0.4
# 2         0      1         0.0
# 3         0      2         0.4
# 4         0      0         0.0

# %%
# dropping attributes which dont effect survival
features_drop = ['Ticket', 'SibSp', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']
train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
train_data.head(10)
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 0       3    0  1.0   0.0    2.0         0      0         0.4
# 1       1    1  3.0   2.0    0.8         1      2         0.4
# 2       3    1  1.0   0.0    2.0         0      1         0.0
# 3       1    1  2.0   2.0    0.8         0      2         0.4
# 4       3    0  2.0   0.0    2.0         0      0         0.0
# 5       3    0  2.0   0.0    2.0         2      0         0.0
# 6       1    0  3.0   2.0    1.6         0      0         0.0
# 7       3    0  0.0   1.0    2.0         0      3         1.6
# 8       3    1  2.0   0.0    2.0         0      2         0.8
# 9       2    1  0.0   2.0    1.8         1      2         0.4

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import numpy as np

# %%
# Using cross validation to compare various models in terms of their accuracy
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
# applying KNN
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.82222222 0.76404494 0.80898876 0.83146067 0.87640449 0.82022472
#  0.85393258 0.79775281 0.84269663 0.84269663]

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 82.6

# %%
# Applying Decision tree
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.76666667 0.80898876 0.7752809  0.76404494 0.87640449 0.7752809
#  0.82022472 0.82022472 0.74157303 0.78651685]

# %%
# decision tree Score
round(np.mean(score)*100, 2)
# Out:
# 79.35

# %%
#Applying Random Forest
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.8        0.82022472 0.79775281 0.7752809  0.87640449 0.80898876
#  0.82022472 0.80898876 0.75280899 0.80898876]

# %%
# Random Forest Score
round(np.mean(score)*100, 2)
# Out:
# 80.7

# %%
#Applying Naive Bayes
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.85555556 0.73033708 0.75280899 0.75280899 0.70786517 0.80898876
#  0.76404494 0.80898876 0.86516854 0.83146067]

# %%
# Naive Bayes Score
round(np.mean(score)*100, 2)
# Out:
# 78.78

# %%
#Applying SVM
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Hp\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Hp\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
#SVM score
round(np.mean(score)*100,2)
# Out:
# 83.5

# %%
# My model is SVM and as shown above its accuracy is more than various other model like KNN,Random Forest,Decision Tree etc.

# %%
clf = SVC()
clf.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
submission.shape
# Out:
# (418, 2)
